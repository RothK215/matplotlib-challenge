# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_tumors = pd.merge(mouse_metadata, study_results)

# Display the data table for preview
mouse_tumors = mouse_tumors[['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)']]
mouse_tumors
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        k403          0           45.000000                 0     Ramicane
# 1        k403          5           38.825898                 0     Ramicane
# 2        k403         10           35.014271                 1     Ramicane
# 3        k403         15           34.223992                 1     Ramicane
# 4        k403         20           32.997729                 1     Ramicane
# ...       ...        ...                 ...               ...          ...
# 1888     z969         25           63.145652                 2     Naftisol
# 1889     z969         30           65.841013                 3     Naftisol
# 1890     z969         35           69.176246                 4     Naftisol
# 1891     z969         40           70.314904                 4     Naftisol
# 1892     z969         45           73.867845                 4     Naftisol
#
#        Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
mice_count = len(mouse_tumors['Mouse ID'].unique())
mice_count
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
mouse_tumors[mouse_tumors.duplicated(['Mouse ID', 'Timepoint'])]
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 909     g989          0           45.000000                 0     Propriva
# 911     g989          5           47.570392                 0     Propriva
# 913     g989         10           49.880528                 0     Propriva
# 915     g989         15           53.442020                 0     Propriva
# 917     g989         20           54.657650                 1     Propriva
#
#         Sex  Age_months  Weight (g)
# 909  Female          21          26
# 911  Female          21          26
# 913  Female          21          26
# 915  Female          21          26
# 917  Female          21          26

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mouse_tumors.loc[mouse_tumors['Mouse ID']=='g989']
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 908     g989          0           45.000000                 0     Propriva
# 909     g989          0           45.000000                 0     Propriva
# 910     g989          5           48.786801                 0     Propriva
# 911     g989          5           47.570392                 0     Propriva
# 912     g989         10           51.745156                 0     Propriva
# 913     g989         10           49.880528                 0     Propriva
# 914     g989         15           51.325852                 1     Propriva
# 915     g989         15           53.442020                 0     Propriva
# 916     g989         20           55.326122                 1     Propriva
# 917     g989         20           54.657650                 1     Propriva
# 918     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = mouse_tumors[mouse_tumors['Mouse ID'] !='g989']
clean_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        k403          0           45.000000                 0     Ramicane
# 1        k403          5           38.825898                 0     Ramicane
# 2        k403         10           35.014271                 1     Ramicane
# 3        k403         15           34.223992                 1     Ramicane
# 4        k403         20           32.997729                 1     Ramicane
# ...       ...        ...                 ...               ...          ...
# 1888     z969         25           63.145652                 2     Naftisol
# 1889     z969         30           65.841013                 3     Naftisol
# 1890     z969         35           69.176246                 4     Naftisol
# 1891     z969         40           70.314904                 4     Naftisol
# 1892     z969         45           73.867845                 4     Naftisol
#
#        Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
mice_count2 = len(clean_df['Mouse ID'].unique())
mice_count2
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
tumor_ave = clean_df.groupby(['Drug Regimen']).mean()['Tumor Volume (mm3)']
tumor_med = clean_df.groupby(['Drug Regimen']).median()['Tumor Volume (mm3)']
tumor_var = clean_df.groupby(['Drug Regimen']).var()['Tumor Volume (mm3)']
tumor_std = clean_df.groupby(['Drug Regimen']).std()['Tumor Volume (mm3)']
tumor_err = clean_df.groupby(['Drug Regimen']).sem()['Tumor Volume (mm3)']
# Assemble the resulting series into a single summary DataFrame.

drug_stats = pd.DataFrame({"Mean Tumor Volume": tumor_ave,
                           "Median Tumor Volume": tumor_med,
                           "Tumor Volume Variance": tumor_var,
                           "Tumor Volume Std. Dev": tumor_std,
                           "Tumor Volume Std. Err.": tumor_err
                          })
drug_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
drug_agg = clean_df.groupby(['Drug Regimen']).agg(['mean', 'median', 'var', 'std', 'sem'])['Tumor Volume (mm3)']
drug_agg
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14428\641998550.py:5: FutureWarning: ['Mouse ID', 'Sex'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   drug_agg = clean_df.groupby(['Drug Regimen']).agg(['mean', 'median', 'var', 'std', 'sem'])['Tumor Volume (mm3)']
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
drug_count1 = clean_df.groupby(['Drug Regimen']).count()['Timepoint']
drug_count1.sort_values(ascending=False).plot(kind = 'bar', ylabel='Number of Mice Tested')
# Out:
# <AxesSubplot:xlabel='Drug Regimen', ylabel='Number of Mice Tested'>

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
drug_count2 = clean_df['Drug Regimen'].value_counts()
plt.bar(drug_count2.index.values,drug_count2.values)
plt.xlabel("Drug Regimen")
plt.xticks(rotation=90)
plt.ylabel("Number of Mice Tested")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
pie = clean_df['Sex'].value_counts().plot(kind='pie', y='sex', autopct='%1.0f%%')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sex_count = clean_df['Sex'].value_counts()
gender = ['Male', 'Female']

plt.pie(sex_count, labels=gender, autopct='%1.0f%%')
plt.title('Sex')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_time = pd.DataFrame(clean_df.groupby(['Mouse ID']).max()['Timepoint'])

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
merged = max_time.merge(mouse_tumors, on=("Mouse ID", "Timepoint"), how = "inner")
merged
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 243     z435         10           48.710661                 0     Propriva
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
# 246     z795         45           65.741070                 3     Naftisol
# 247     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
cric = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
cric_list = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in cric:
    #Locate the rows which contain mice on each drug and get the tumor volumes
    located = merged.loc[(merged['Drug Regimen']==drug)]
    volume = (located['Tumor Volume (mm3)'])
    
    # add subset 
    cric_list.append(volume)
    
    # Determine outliers using upper and lower bounds
    quartiles = volume.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq

    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f"{drug}'s potential outliers: LB: {lower_bound} UB: {upper_bound}")
# Out:
# Capomulin's potential outliers: LB: 20.70456164999999 UB: 51.83201549
# Ramicane's potential outliers: LB: 17.912664470000003 UB: 54.30681135
# Infubinol's potential outliers: LB: 36.83290494999999 UB: 82.74144559000001
# Ceftamin's potential outliers: LB: 25.355449580000002 UB: 87.66645829999999

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
plt.boxplot(cric_list, labels=cric,
           flierprops={'marker': 'o', 'markersize': 10, 'markerfacecolor': 'yellow'})
plt.ylabel("Final Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
mouse_tumors.loc[mouse_tumors['Drug Regimen']=='Capomulin']
mouse = mouse_tumors.loc[mouse_tumors['Mouse ID']=='s185']
mouse
tumor=mouse['Tumor Volume (mm3)']
time=mouse['Timepoint']
plt.plot(time, tumor)
plt.xlabel("Timepoint (Days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Tumor Rate for Subject: s185")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
sm = mouse_tumors.loc[mouse_tumors['Drug Regimen']=='Capomulin']
sm_redone = sm.groupby(['Mouse ID', 'Weight (g)']).median()['Tumor Volume (mm3)']
sm_final = pd.DataFrame(sm_redone).reset_index()

x = sm_final['Weight (g)']
y = sm_final['Tumor Volume (mm3)']
plt.scatter(x, y)
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
x = sm_final['Weight (g)']
y = sm_final['Tumor Volume (mm3)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = (round(slope,2)) + (round(intercept,2))

weight = sm_final.iloc[:, 1]
tumvol = sm_final.iloc[:, 2]
corr = st.pearsonr(weight, tumvol)
print(f'The correlation between mouse weight and the average tumor volume is {round(corr[0],2)}')

plt.scatter(x, y)
plt.plot(x, regress_values, "r-")
plt.annotate(line_eq,(5.8,0.8),color="red")
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.77
